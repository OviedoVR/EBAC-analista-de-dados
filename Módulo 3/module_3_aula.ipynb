# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Fluxo Condicional & Repetição
# Caderno de **Aula**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Estrutura condicional if / else / elif;</li>
#   <li>Estrutura condicional try / catch / finally;</li>
#   <li>Estrutura de repetição for / in.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Aulas**

# %% [markdown]
# ## 1\. Estrutura condicional if / else / elif

# %% [markdown]
# ### **1.1. if / else**

# %% [markdown]
# Estrutura de alteração de fluxo lógico do código, avalia um valor booleano ou uma comparação lógica. **Note** a identação do código.

# %% [markdown]
# ```python
# if <booleano / comparação lógica> == True:
#   <execute este código>
# else:
#   <senão execute este código>
# ```

# %%
if False:
  print("Verdadeiro")
else:
  print("Falso")
# Out:
# Falso

# %% [markdown]
# **Exemplo**: Código de segurança de um cartão de crédito

# %%
codigo_de_seguranca = '291'
codigo_de_seguranca_cadastro = '010'

pode_efetuar_pagamento = codigo_de_seguranca == codigo_de_seguranca_cadastro
print(pode_efetuar_pagamento)
# Out:
# False

# %%
if pode_efetuar_pagamento:
  print("Pagamento efetuado")
else:
  print("Erro: Código de segurança inválido")
# Out:
# Erro: Código de segurança inválido

# %%
if codigo_de_seguranca == codigo_de_seguranca_cadastro:
  print("Pagamento efetuado")
else:
  print("Erro: Código de segurança inválido")
# Out:
# Erro: Código de segurança inválido

# %% [markdown]
# **Exemplo**: Código e senha de segurança de um cartão de crédito

# %%
codigo_de_seguranca = '852'
codigo_de_seguranca_cadastro = '852'

senha = '7783'
senha_cadastro = '7783'

# %% [markdown]
# Revisitando a tabela da verdade:

# %% [markdown]
# | CÓDIGO        | SENHA        | | | CÓDIGO OR SENHA   | | CÓDIGO AND SENHA  | | NOT CÓDIGO    |
# |----------|----------|-|-|----------|-|----------|-|----------|
# | **TRUE** | **TRUE** | | | **TRUE** | | **TRUE** | | FALSE    |
# | **TRUE** | FALSE    | | | **TRUE** | | FALSE    | | FALSE    |
# | FALSE    | FALSE    | | | FALSE    | | FALSE    | | **TRUE** |
# | FALSE    | **TRUE** | | | **TRUE** | | FALSE    | | **TRUE** |

# %%
if (codigo_de_seguranca == codigo_de_seguranca_cadastro) & (senha == senha_cadastro):
  print("Pagamento efetuado")
else:
  print("Erro: Pagamento não efetuado")
# Out:
# Pagamento efetuado

# %%
if (codigo_de_seguranca != codigo_de_seguranca_cadastro) | (senha != senha_cadastro):
  print("Erro: Pagamento não efetuado")
else:
  print("Pagamento efetuado")
# Out:
# Pagamento efetuado

# %% [markdown]
# ### **1.2. if / elif / else**

# %% [markdown]
# Podemos também avaliar múltipla condições.

# %% [markdown]
# ```python
# if <1º booleano / 1ª comparação lógica> == True:
#   <execute este código se a primeira condição for verdade>
# elif <2º booleano / 2ª comparação lógica> == True:
#   <execute este código se a segunda condição for verdade>
# else:
#   <senão execute este código>
# ```

# %%
codigo_de_seguranca = '802'
codigo_de_seguranca_cadastro = '852'

senha = '7703'
senha_cadastro = '7783'

# %% [markdown]
# | CÓDIGO        | SENHA        | | | CÓDIGO AND SENHA  | MENSAGEM |
# |----------|----------|-|-|----------|-|
# | **TRUE** | **TRUE** | | | **TRUE** | Pagamento efetuado |
# | **TRUE** | FALSE    | | | FALSE    | Erro: Senha inválida |
# | FALSE    | FALSE    | | | FALSE    | Erro: Código de segurança e senha inválidos |
# | FALSE    | **TRUE** | | | FALSE    | Erro: Código de segurança inválido |

# %%
if (codigo_de_seguranca == codigo_de_seguranca_cadastro) & (senha == senha_cadastro):
  print("Pagamento efetuado")

elif (codigo_de_seguranca != codigo_de_seguranca_cadastro) & (senha == senha_cadastro):
  print("Erro: Código de segurança inválido")

elif (codigo_de_seguranca == codigo_de_seguranca_cadastro) & (senha != senha_cadastro):
  print("Erro: Senha inválida inválida")

else:
  print("Erro: Código de segurança e senha inválidos")
# Out:
# Erro: Código de segurança e senha inválidos

# %% [markdown]
# **Exercício criado por VRO** (Módulos anteriores):
#
# # **Entrando na corretora de valores**
#
# Simule a entrada de um investidor em sua corretora de valores. Leve como base:
#
# 1. **Login**;
# 2. **Senha**;
# 3. **Token** (número gerado e atualizado a cada 30 segundos).
#
# Considerar as seguintes situações:
#
#
# 1. O usuário errou o **login** e a **senha**;
# 2. O usuário errou a **senha**;
# 3. O usuário errou o **token**;
# 4. O usuário acessou o sistema.
#
# Para isso, use *if/else/elif*.

# %%
login_cadastrado = 'InvestidorPF'
senha_cadastrada = 'dividendos'

# %%
#Situação 1: 
login_1 = 'Investidorpf'
senha_1 = 'divid3ndos'
#Aqui não gera o token.

#Situação 2:
login_2 = 'InvestidorPF'
senha_2 = 'div1dendos'
#Aqui também não gera o token.

#Situação 3:
login_3 = 'InvestidorPF'
senha_3 = 'dividendos'
token_gerado_3 = '249763'
token_informado_3 = '249767'

#Situação 4:
login_4 = 'InvestidorPF'
senha_4 = 'dividendos'
token_gerado_4 = '249763'
token_informado_4 = '249763'

#Resolvendo com fluxos condicionais (if/else/elif):
if (login_1 == login_cadastrado) & (senha_1 == senha_cadastrada):
  print('Situação 1: Acesso liberado')

else:
  print('Situação 1: Acesso negado')

if (login_2 == login_cadastrado) & (senha_2 == senha_cadastrada):
    print('Situação 2: Acesso liberado')

else:
  print('Situação 2: Acesso negado')

if (login_3 == login_cadastrado) & (senha_3 == senha_cadastrada) & (token_informado_3 == token_gerado_3):
    print('Situação 3: Acesso liberado')

else:
  print('Situação 3: Acesso negado')

if (login_4 == login_cadastrado) & (senha_4 == senha_cadastrada) & (token_informado_4 == token_gerado_4):
    print('Situação 4: Acesso liberado')

else:
  print('Situação 4: Acesso negado')
# Out:
# Situação 1: Acesso negado
# Situação 2: Acesso negado
# Situação 3: Acesso negado
# Situação 4: Acesso liberado

# %% [markdown]
# ## 2\. Estrutura condicional try /except / finally

# %% [markdown]
# ### **2.1. Exceção**

# %% [markdown]
# Exceções são erros que podem acontecer durante a execução do nosso código.

# %% [markdown]
# **Exemplo**: Erro de operações numéricas impossíveis

# %%
preco = 132.85
pessoas = 0

# %%
valor_por_pessoa = preco / pessoas

# %% [markdown]
# **Exemplo**: Erro por combinações de tipos diferentes

# %%
nome = 'Andre Perez'
idade = True

# %%
apresentacao = 'Fala pessoal, meu nome é ' + nome + ' e eu tenho ' + idade + ' anos'

# %% [markdown]
# **Exemplo**: Erro de indexação de estrutura de dados

# %%
anos = [2019, 2020, 2021]

# %%
ano_atual = anos[3]

# %%
cursos = {
    'python': {
        'nome': 'Python para Análise de Dados', 'duracao': 2.5
    }, 
    'sql': {
        'nome': 'SQL para Análise de Dados', 'duracao': 2
    }
}

# %%
curso_atual = cursos['analista']

# %% [markdown]
# ### **2.2. try / except**

# %% [markdown]
# Estrutura para tratar exceções:

# %%
preco = 132.85
pessoas = 0

try:
  valor_por_pessoa = preco / pessoas
  print(valor_por_pessoa)
except ZeroDivisionError:
  print('Número de pessoas inválido. Espera-se um valor maior que 0 e obteve-se um valor igual a ' + str(pessoas))
# Out:
# Número de pessoas inválido. Espera-se um valor maior que 0 e obteve-se um valor igual a 0

# %%
anos = [2019, 2020, 2021]

try:
  ano_atual = anos[3]
  print(ano_atual)
except:
  print('Lista de anos é menor que o valor escolhido. Espera-se um valor entre 0 e ' + str(len(anos) - 1))
# Out:
# Lista de anos é menor que o valor escolhido. Espera-se um valor entre 0 e 2

# %%
anos = [2019, 2020, 2021]

try:
  ano_atual = anos[3]
  print(ano_atual)
except Exception as exc:
  print('Descrição da exceção: ' + str(exc))
  print('Tipo da exceção: ' + str(type(exc)))
  print('Lista de anos é menor que o valor escolhido. Espera-se um valor entre 0 e ' + str(len(anos) - 1))

# %%
anos = [2019, 2020, 2021]

try:
  ano_atual = anos[3]
  print(ano_atual)
except IndexError:
  print('Lista de anos é menor que o valor escolhido. Espera-se um valor entre 0 e ' + str(len(anos) - 1))
except Exception as exc:
  print(exc)
  print('Erro genérico')

# %%
biomateriais = ['Titanium','Bioglass','PCL']

try:
  biomaterial_selecionado = biomateriais[3]
  print(biomaterial_selecionado)
except Exception as exc:
  print('Erro (descrição): ' + str(exc))
  print('Erro (tipo): ' + str(type(exc)))
  print('A lista possui apenas ' + str(len(biomateriais)) + ' elementos, ou seja, o último índice é ' + str(len(biomateriais)-1))
# Out:
# Erro (descrição): list index out of range
# Erro (tipo): <class 'IndexError'>
# A lista possui apenas 3 elementos, ou seja, o último índice é 2

# %%
Simulacoes = ['ab initio', 'docking', 'DM']

try:
  Simulacao_escolhida = Simulacoes[4]
except IndexError:
  print('A lista possui apenas ' + str(len(Simulacoes)) + ', ou seja, os indíces vao de 0:' + str(len(Simulacoes) - 1) + '.')
# Out:
# A lista possui apenas 3, ou seja, os indíces vao de 0:2.

# %% [markdown]
# ### **2.3. try / except / finally**

# %%
nome = 'Andre Perez'
idade = 19

try:
  apresentacao = 'Fala pessoal, meu nome é ' + nome + ' e eu tenho ' + idade + ' anos'
  print(apresentacao)
except TypeError:
  idade = str(idade)
finally:
  print('Segunda chance')
  apresentacao = 'Fala pessoal, meu nome é ' + nome + ' e eu tenho ' + idade + ' anos'
  print(apresentacao)
# Out:
# Segunda chance
# Fala pessoal, meu nome é Andre Perez e eu tenho 19 anos

# %% [markdown]
# **Problema criado por VRO**
#
# ### **Ensinando indexação de listas com o erro a um estudande de Python**
#
# Suponha que um estudante inciante em Python está aprendendo sobre listas e se depara com a seguinte lista contento 3 tipos de biomateriais (um metálico, um cerâmico e outro polimérico):
#
#
# ```
# biomateriais = ['Titanium','Bioglass','PCL']
# ```
#
# Eese mesmo estudante busca selecionar o último biomaterial da lista e armazenar na variável **biomaterial_selecionado**, porém ele usa o seguinte código:
#
# ```
# biomateriais = ['Titanium','Bioglass','PCL']
# biomaterial_selecionado = biomateriais[3]
# print(biomaterial_selecionado)
# ```
#
# Isso nos leva a um **Erro de Indexação**, pois a lista começa no índice [0] e termina no índice [2]. Faça uso das estruturas condicionais **try/excepet/finally** para corrigir o problema, de modo que o estudante receba uma segunda chance e informe o novo índice para obter corretamente o último item da lista (o *PCL*) e imprimí-lo.

# %%
#Lista com os biomateriais:
biomateriais = ['Titanium','Bioglass','PCL']

#Simulando o erro do estudante:
try:
  biomaterial_selecionado = biomateriais[5]
  print(biomaterial_selecionado)

#Informando o porquê de isso gerar um erro:
except IndexError as ie:
  print('A lista possui apenas ' + str(len(biomateriais)) + ' elementos, ou seja, o último índice é ' + str(len(biomateriais)-1))

#Dando uma segunda chance ao estudando e corrigindo o problema:
finally:
  #O estuande deve entrar um novo índice que vai ser armezando como uma variável inteira.
  novo_indice = int(input('Segunda chance, entre o novo índice: '))
  #A seleção do biomaterial se dá, agora, com base no novo índice:
  biomaterial_selecionado = biomateriais[novo_indice]
  #Impressão na tela como modo de verificação:
  print(biomaterial_selecionado)
# Out:
# A lista possui apenas 3 elementos, ou seja, o último índice é 2
# Segunda chance, entre o novo índice: 2
# PCL

# %% [markdown]
# ## 3\. Estrutura repetição for / in

# %% [markdown]
# ### **3.1. for / in**

# %% [markdown]
# Estrutura que permite a execução repetida de um bloco de código repetidas vezes.

# %% [markdown]
# ```python
# for variavel_temporaria in coleção:
#   <execute este código>
# ```

# %% [markdown]
# ### **3.2. for / in / range**

# %% [markdown]
# Estrutura que permite a execução repetida de um bloco de código **n** vezes.

# %%
for valor in range(6):
  print(valor)

# %%
soma = 0

for valor in range(0, 10):
  soma = soma + valor
  print(soma)

#print(soma)
# Out:
# 0
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45

# %%
for multiplo_dois in range(2, 10, 3):
  print(multiplo_dois)

# %%
for valor in range(11):
  divisao_por_2 = valor/2
  print(f'Divisão por 2: {divisao_por_2}')

for x in range (0, 30, 5):
  x_ao_quadrado = x**2
  print(f'Resultado: x({x}), x^2 ({x_ao_quadrado})')
# Out:
# Divisão por 2: 0.0
# Divisão por 2: 0.5
# Divisão por 2: 1.0
# Divisão por 2: 1.5
# Divisão por 2: 2.0
# Divisão por 2: 2.5
# Divisão por 2: 3.0
# Divisão por 2: 3.5
# Divisão por 2: 4.0
# Divisão por 2: 4.5
# Divisão por 2: 5.0
# Resultado: x(0), x^2 (0)
# Resultado: x(5), x^2 (25)
# Resultado: x(10), x^2 (100)
# Resultado: x(15), x^2 (225)
# Resultado: x(20), x^2 (400)
# Resultado: x(25), x^2 (625)

# %% [markdown]
# ### **3.3. for / in / list**

# %% [markdown]
# Estrutura que permite a execução de um bloco de código para todos os elementos de uma lista.

# %%
frutas = ['maca', 'banana', 'laranja', 'uva', 'pera']

for fruta in frutas:
  print(fruta)

# %%
cidades = ['Florianópolis', 'Chapecó', 'Joinville', 'Salvador', 'Natal']
estado = []

for cidade in cidades:
  
  if (cidade == 'Florianópolis') | (cidade == 'Chapecó') | (cidade == 'Joinville'):
    estado = 'SC'
  elif (cidade == 'Salvador'):
    estado = 'BA'
  else:
    estado = 'PE'

  print(f'Cidade: {cidade}, Estado: {estado}')
# Out:
# Cidade: Florianópolis, Estado: SC
# Cidade: Chapecó, Estado: SC
# Cidade: Joinville, Estado: SC
# Cidade: Salvador, Estado: BA
# Cidade: Natal, Estado: PE

# %%
frase = 'Fala pessoal, meu nome é André Perez.'

for caracter in frase:
  if (caracter == 'A') | (caracter == 'z'):
    print(f"A letra '{caracter}' está presente na frase.")
# Out:
# A letra 'A' está presente na frase.
# A letra 'z' está presente na frase.

# %% [markdown]
# ### **3.4. for / in / dict**

# %% [markdown]
# Estrutura que permite a execução de um bloco de código para todos os elementos de um dicionário.

# %%
credito = {'123': 750, '456': 812, '789': 980}

# %%
for chave, valor in credito.items():
  print(f'Para o documento {chave}, o valor do escore de crédito é {valor}.')
  print('\n')

# %%
for chave in credito.keys():
  print(chave)
  print(credito[chave])
  print(f'Para o documento {chave}, o valor do escore de crédito é {credito[chave]}.')
  print('\n')

# %%
for valor in credito.values():
  print(valor)
  print(f'O valor do escore de crédito é {valor}, mas não temos mais as chaves :(.')
  print('\n')

# %%
notebooks_orcamento = {
    'Dell': [3000, 3100],
    'Lenovo': [2800, 2950],
    'Apple': [5000, 7500],
    'Compaq': [900, 1270] 
    }


print('Segue o orçamento referente aos notebooks e respectivas marcas:')

#Iteração para imprimir as chaves e os valores:
for chave, valor in notebooks_orcamento.items():
  print(f'Marca: {chave}, Valor: R${valor}.')

print('\n')

for chave in notebooks_orcamento.keys():
  print(f'A marca desse notebook é: {chave}')

print('\n')

for value in notebooks_orcamento.values():
  print(f'O valor de notebooks é: R${value}.')
# Out:
# Segue o orçamento referente aos notebooks e respectivas marcas:
# Marca: Dell, Valor: R$[3000, 3100].
# Marca: Lenovo, Valor: R$[2800, 2950].
# Marca: Apple, Valor: R$[5000, 7500].
# Marca: Compaq, Valor: R$[900, 1270].
#
#
# A marca desse notebook é: Dell
# A marca desse notebook é: Lenovo
# A marca desse notebook é: Apple
# A marca desse notebook é: Compaq
#
#
# O valor de notebooks é: R$[3000, 3100].
# O valor de notebooks é: R$[2800, 2950].
# O valor de notebooks é: R$[5000, 7500].
# O valor de notebooks é: R$[900, 1270].

# %% [markdown]
# ### **3.5. break / continue**

# %% [markdown]
# Estrutura que permite a quebra ou o avanço de um laço de repetição.

# %%
for i in range(0, 10*10*10*10*10*10):
  print(i)
  if i == 10:
    break

# %%
numero = 3

if numero % 2 == 0:
  print(f'O numero {numero} é par')
else:
  print(f'O numero {numero} é impar')

# %%
numeros = [361, 553, 194, 13, 510, 33, 135]

for numero in numeros:

  if numero % 2 == 0:
    print(f'O numero {numero} é par')
    break
  else:
    print(f'O numero {numero} é impar')
# Out:
# O numero 361 é impar
# O numero 553 é impar
# O numero 194 é par

# %%
numeros = [361, 553, 194, 13, 510, 33, 135]

for numero in numeros:

  if numero % 2 == 0:
    print(f'O numero {numero} é par')
    break
  else:
    continue
    print(f'O numero {numero} é impar')
# Out:
# O numero 194 é par

# %% [markdown]
# ## Exercício by VRO:
#
# Criar um script para quebrar um laço de repetição (utilizando o **break**) quando não temos mais um quadrado perfeito par. Para isso, crie uma lista qualquer antes de resolver o problema.

# %%
import numpy as np
valores = [2, 4, 16, 25, 144, 121, 64, 81, 343, 51]

#Código para quebrar o loop e continuar a iteração:
for valor in valores:
  a_sqrd = valor**2

  #Informa-se primeiro, a condição do porquê devo parar!
  if a_sqrd % 2 != 0:
    print(f'O valor {valor}, tem como quadrado {a_sqrd} e é ímpar.')
    break
  else:
    print(f'O valor {valor}, tem como quadrado {a_sqrd} e é par.')
# Out:
# O valor 2, tem como quadrado 4 e é par.
# O valor 4, tem como quadrado 16 e é par.
# O valor 16, tem como quadrado 256 e é par.
# O valor 25, tem como quadrado 625 e é ímpar.

# %%
import numpy as np
valores = [2, 4, 16, 25, 144, 121, 64, 81, 343, 51]

#Código para quebrar o loop e continuar a iteração:
for valor in valores:
  a_sqrd = valor**2

  #Informa-se primeiro, a condição do porquê devo parar!
  if a_sqrd % 2 != 0:
    print(f'O valor {valor}, tem como quadrado {a_sqrd} e é ímpar.')
    break
  else:
    continue
    print(f'O valor {valor}, tem como quadrado {a_sqrd} e é par.')
# Out:
# O valor 25, tem como quadrado 625 e é ímpar.
