# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Pipeline de Dados do Telegram I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Contexto;</li>
#   <li>Telegram;</li>
#   <li>Dados.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Telegram.

# %% [markdown]
# Replique as atividades da aula 2.

# %% [markdown]
# 1.1. Crie uma conta no **Telegram** caso não possua uma e faça o login na versão web da ferramenta através desse [link](https://web.telegram.org).

# %% [markdown]
# 1.2. Crie um *bot*.

# %% [markdown]
# 1.3. Crie um grupo e adicione o *bot*.

# %% [markdown]
# 1.4. Torne o *bot* administrador do grupo.

# %% [markdown]
# 1.5. Desabilite a opção de adicionar o *bot* a novos grupos.

# %% [markdown]
# 1.6. Envie diversos tipos de mensagens no grupo (text, imagem, arquivos, video, áudio, etc.) e as consuma utilizand a API de *bots* do **Telegram**.

# %% [markdown]
# > **Nota:** A documentação completa da API pode ser encontrada neste [link](https://core.telegram.org/bots/api)

# %% [markdown]
# **Evidência Bot do Telegram**
# ![pipegram-bot.png](data:image/png;base64,...)'

# %% [markdown]
# **Evidência Grupo do Telegram**
# ![Telegram_group.png](data:image/png;base64,...)

# %% [markdown]
# > **Consumindo o conteúdo do grupo via API**

# %%
from getpass import getpass
import json
import requests

# %%
token = getpass()
# Out:
# ··········

# %%
# URL do bot a ser consumido via API do Telegram:
base_url = f'https://api.telegram.org/bot{token}'

# método GetMe:
resposta = requests.get(url=f'{base_url}/getme')
print(json.dumps(json.loads(resposta.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": {
#     "id": 5442183827,
#     "is_bot": true,
#     "first_name": "pipegram_bot",
#     "username": "pipegram_bot",
#     "can_join_groups": false,
#     "can_read_all_group_messages": false,
#     "supports_inline_queries": false
#   }
# }

# %%
# método GetUpdates (checar por conteúdos enviados):
resposta = requests.get(url=f'{base_url}/getupdates')
print(json.dumps(json.loads(resposta.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": [
#     {
#       "update_id": 431612816,
#       "message": {
#         "message_id": 3,
#         "from": {
#           "id": 1612220101,
#           "is_bot": false,
#           "first_name": "Vin\u00edcius",
#           "last_name": "Oviedo",
#           "username": "ViniciusOviedo"
#         },
#         "chat": {
#           "id": -1001613579224,
#           "title": "Pipegram Bot",
#           "type": "supergroup"
#         },
#         "date": 1664193019,
#         "text": "Testando uma mensagem"
#       }
#     },
#     {
#       "update_id": 431612817,
#       "message": {
#         "message_id": 4,
#         "from": {
#           "id": 1612220101,
#           "is_bot": false,
#           "first_name": "Vin\u00edcius",
#           "last_name": "Oviedo",
#           "username": "ViniciusOviedo"
#         },
#         "chat": {
#           "id": -1001613579224,
#           "title": "Pipegram Bot",
#           "type": "supergroup"
#         },
#         "date": 1664193057,
#         "text": "Ol\u00e1, mundo!"
#       }
#     },
#     {
#       "update_id": 431612818,
#       "message": {
#         "message_id": 5,
#         "from": {
#           "id": 1612220101,
#           "is_bot": false,
#           "first_name": "Vin\u00edcius",
#           "last_name": "Oviedo",
#           "username": "ViniciusOviedo"
#         },
#         "chat": {
#           "id": -1001613579224,
#           "title": "Pipegram Bot",
#           "type": "supergroup"
#         },
#         "date": 1664211095,
#         "photo": [
#           {
#             "file_id": "AgACAgEAAx0CYC1D2AADBWMx2JdbS-n7gkLV1MrlXCT3Is-bAALtqjEbS-SJRcfR19V3n3NNAQADAgADcwADKQQ",
#             "file_unique_id": "AQAD7aoxG0vkiUV4",
#             "file_size": 695,
#             "width": 43,
#             "height": 90
#           },
#           {
#             "file_id": "AgACAgEAAx0CYC1D2AADBWMx2JdbS-n7gkLV1MrlXCT3Is-bAALtqjEbS-SJRcfR19V3n3NNAQADAgADbQADKQQ",
#             "file_unique_id": "AQAD7aoxG0vkiUVy",
#             "file_size": 7005,
#             "width": 152,
#             "height": 320
#           },
#           {
#             "file_id": "AgACAgEAAx0CYC1D2AADBWMx2JdbS-n7gkLV1MrlXCT3Is-bAALtqjEbS-SJRcfR19V3n3NNAQADAgADeAADKQQ",
#             "file_unique_id": "AQAD7aoxG0vkiUV9",
#             "file_size": 30179,
#             "width": 379,
#             "height": 800
#           },
#           {
#             "file_id": "AgACAgEAAx0CYC1D2AADBWMx2JdbS-n7gkLV1MrlXCT3Is-bAALtqjEbS-SJRcfR19V3n3NNAQADAgADeQADKQQ",
#             "file_unique_id": "AQAD7aoxG0vkiUV-",
#             "file_size": 53408,
#             "width": 606,
#             "height": 1280
#           }
#         ],
#         "caption": "Storytelling print"
#       }
#     },
#     {
#       "update_id": 431612819,
#       "message": {
#         "message_id": 6,
#         "from": {
#           "id": 1612220101,
#           "is_bot": false,
#           "first_name": "Vin\u00edcius",
#           "last_name": "Oviedo",
#           "username": "ViniciusOviedo"
#         },
#         "chat": {
#           "id": -1001613579224,
#           "title": "Pipegram Bot",
#           "type": "supergroup"
#         },
#         "date": 1664212116,
#         "text": "Mesangem para o exerc\u00edcio do m\u00f3dulo 43 do curso Analista de Dados da EBAC"
#       }
#     },
#     {
#       "update_id": 431612820,
#       "message": {
#         "message_id": 7,
#         "from": {
#           "id": 1612220101,
#           "is_bot": false,
#           "first_name": "Vin\u00edcius",
#           "last_name": "Oviedo",
#           "username": "ViniciusOviedo"
#         },
#         "chat": {
#           "id": -1001613579224,
#           "title": "Pipegram Bot",
#           "type": "supergroup"
#         },
#         "date": 1664212184,
#         "voice": {
#           "duration": 8,
#           "mime_type": "audio/ogg",
#           "file_id": "AwACAgEAAx0CYC1D2AADB2Mx3NjfRgObI8pZ7MXGxvmWdhKPAALmAQACS-SJRaE-3v0lyDN6KQQ",
#           "file_unique_id": "AgAD5gEAAkvkiUU",
#           "file_size": 167320
#         }
#       }
#     }
#   ]
# }
