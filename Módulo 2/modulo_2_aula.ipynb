# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo 02** | Python: Estruturas de Dados
# Caderno de **Aula**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Listas;</li>
#   <li>Conjuntos;</li>
#   <li>Dicionários.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Aulas**

# %% [markdown]
# ## 1\. Listas

# %% [markdown]
# ### **1.1. Motivação**

# %% [markdown]
# O aplicativo do seu banco registra toda a sua movimentação financeira. O final do dia, o app consolida o saldo final para que você possa controlar sua vida financeira.

# %%
dia_11_saldo_inicial = 1000

# %%
dia_11_transacao_1 = 243
dia_11_transacao_2 = -798.58
dia_11_transacao_3 = 427.12
dia_11_transacao_4 = -10.91

# %%
dia_11_saldo_final = dia_11_saldo_inicial + dia_11_transacao_1 + dia_11_transacao_2 + dia_11_transacao_3 + dia_11_transacao_4

# %%
print(dia_11_saldo_final)
# Out:
# 860.63

# %% [markdown]
# Será que exista uma forma melhor de armazenar as transações diárias?

# %% [markdown]
# ### **1.2. Definição**

# %% [markdown]
# Armazenam sequências mutáveis e ordenadas de valores. São do tipo `list`:

# %%
usuario_web = ['André Perez', 'andre.perez', 'andre123', 'andre.perez@gmail.com']

print(usuario_web)
print(type(usuario_web))
# Out:
# ['André Perez', 'andre.perez', 'andre123', 'andre.perez@gmail.com']
# <class 'list'>

# %%
idade = 20
saldo_em_conta = 723.15
usuario_loggedin = True

usuario_web = ['André Perez', idade, 'andre.perez', 'andre123', 'andre.perez@gmail.com', saldo_em_conta, usuario_loggedin]

print(usuario_web)
print(type(usuario_web))
# Out:
# ['André Perez', 20, 'andre.perez', 'andre123', 'andre.perez@gmail.com', 723.15, True]
# <class 'list'>

# %% [markdown]
# ### **1.3. Operações**

# %% [markdown]
# As operações da estrutura do tipo *list* são:
#
#
# *   `+` (concatenação).

# %% [markdown]
# **Exemplo**: Fabricantes de *hardware* mobile

# %%
fabricantes_mobile_china = ['xiaomi', 'huawei']
fabricantes_mobile_eua = ['apple', 'motorola']
fabricantes_mobile = fabricantes_mobile_china + fabricantes_mobile_eua

print(fabricantes_mobile_china)
print(fabricantes_mobile_eua)
print(fabricantes_mobile)
# Out:
# ['xiaomi', 'huawei']
# ['apple', 'motorola']
# ['xiaomi', 'huawei', 'apple', 'motorola']

# %% [markdown]
# Outra operação muito utilizada é a de fatiamento (*slicing*), semelhante ao de *strings*:

# %% [markdown]
# Fatiamento fixo:

# %%
print(f'0: {fabricantes_mobile[0]}')
print(f'-1: {fabricantes_mobile[-1]}')
# Out:
# 0: xiaomi
# -1: motorola

# %% [markdown]
# Fatiamento por intervalo:

# %%
fabricantes_mobile_china = fabricantes_mobile[0:2]
fabricantes_mobile_eua = fabricantes_mobile[2:len(fabricantes_mobile)]

print('china: ' + str(fabricantes_mobile_china))
print('eua: ' + str(fabricantes_mobile_eua))
# Out:
# china: ['xiaomi', 'huawei']
# eua: ['apple', 'motorola']

# %%
corretoras_BR = ['Rico', 'Easy Invest','Modal Mais', 'BTG Pactual', 
                 'Banco Inter', 'Toro']
corretoras_US = ['Avenue', 'Passfolio']
minhas_corretoras = corretoras_BR + corretoras_US
print(minhas_corretoras)
# Out:
# ['Rico', 'Easy Invest', 'Modal Mais', 'BTG Pactual', 'Banco Inter', 'Toro', 'Avenue', 'Passfolio']

# %%
minhas_corretoras[6:8]
print('As corretoras brasileiras da lista são: ' + str(minhas_corretoras[0:6]))
print('As corretoras estrangeiras (USA) da lista são: ' 
      + str(minhas_corretoras[-2:]))
# Out:
# As corretoras brasileiras da lista são: ['Rico', 'Easy Invest', 'Modal Mais', 'BTG Pactual', 'Banco Inter', 'Toro']
# As corretoras estrangeiras (USA) da lista são: ['Avenue', 'Passfolio']

# %%
minhas_corretoras[2] = 'XP Investimentos'

#Inserindo uma corretora na posição 4 (Real: i=5):
minhas_corretoras.insert(4,'Clear Corretora')
#print(minhas_corretoras)

#Adicionando uma corretora estrangeira:
minhas_corretoras.append('Stake')
#minhas_corretoras

#Removendo uma corretora pelo índice:
minhas_corretoras.pop(4)
#minhas_corretoras

#Removendo uma corretora pelo valor:
minhas_corretoras.remove('Banco Inter')
minhas_corretoras
# Out:
# ['Rico',
#  'Easy Invest',
#  'XP Investimentos',
#  'BTG Pactual',
#  'Toro',
#  'Avenue',
#  'Passfolio',
#  'Stake']

# %% [markdown]
# Podemos adicionar elementos a uma posição específica da lista:

# %%
print(fabricantes_mobile)
# Out:
# ['xiaomi', 'huawei', 'apple', 'motorola']

# %%
fabricantes_mobile[2] = 'nokia'
print(fabricantes_mobile)
# Out:
# ['xiaomi', 'huawei', 'nokia', 'motorola']

# %% [markdown]
# ### **1.4. Métodos**

# %% [markdown]
# São métodos nativos do Python que nos ajudam a trabalhar no dia a dia com listas.

# %%
juros = [0.05, 0.07, 0.02, 0.04, 0.08]
print(juros)
# Out:
# [0.05, 0.07, 0.02, 0.04, 0.08]

# %%
# inserir um elemento sem substituir: list.insert(index, val)
juros.insert(0, 0.10)
print(juros)
# Out:
# [0.1, 0.05, 0.07, 0.02, 0.04, 0.08]

# %%
# inserir um elemento no fim da lista: list.append(val)
juros.append(0.09)
print(juros)
# Out:
# [0.1, 0.05, 0.07, 0.02, 0.04, 0.08, 0.09]

# %%
# remover um elemento pelo valor: list.remove(val)
juros.remove(0.1)
print(juros)
# Out:
# [0.05, 0.07, 0.02, 0.04, 0.08, 0.09]

# %%
# remover um elemento pelo índice: list.pop(val)
terceiro_juros = juros.pop(2)
print(terceiro_juros)
# Out:
# 0.02

# %%
print(juros)
# Out:
# [0.05, 0.07, 0.04, 0.08, 0.09]

# %% [markdown]
# ### **1.5. Conversão**

# %% [markdown]
# Podemos converter alguns tipos de variáveis em listas, como *strings*.

# %%
email = 'andre.perez@gmail.com'
caracteres_email = list(email)

print(email)
print(caracteres_email)
# Out:
# andre.perez@gmail.com
# ['a', 'n', 'd', 'r', 'e', '.', 'p', 'e', 'r', 'e', 'z', '@', 'g', 'm', 'a', 'i', 'l', '.', 'c', 'o', 'm']

# %%
gmail = 'oviedo.vinicius@gmail.com'
caracteres_gmail = list(gmail)

print(gmail)
print(caracteres_gmail)
print('Extraindo o "arroba": ', caracteres_gmail[15])
# Out:
# oviedo.vinicius@gmail.com
# ['o', 'v', 'i', 'e', 'd', 'o', '.', 'v', 'i', 'n', 'i', 'c', 'i', 'u', 's', '@', 'g', 'm', 'a', 'i', 'l', '.', 'c', 'o', 'm']
# Extraindo o "arroba":  @

# %% [markdown]
# ### **1.6. Revisitando a motivação**

# %%
dia_11_saldo_inicial = 1000

# %%
dia_11_transacoes = []

dia_11_transacoes.append(243)
dia_11_transacoes.append(-798.58)
dia_11_transacoes.append(427.12)
dia_11_transacoes.append(-10.91)

print(dia_11_transacoes)
# Out:
# [243, -798.58, 427.12, -10.91]

# %%
dia_11_saldo_final = dia_11_saldo_inicial + dia_11_transacoes[0] + dia_11_transacoes[1] + dia_11_transacoes[2] + dia_11_transacoes[3]
print(dia_11_saldo_final)
# Out:
# 860.63

# %% [markdown]
# Crie um *script* para ir constando os **pagamentos do cartão de crédito** em ***5 dias**. Considere o saldo devedor inicial de **R$250,00**.

# %%
saldo_devedor_inicial = -250

# %%
#Criar uma lista vazia para pagamentos:
pagamentos = list()

#Adicionar os elementos na lista em ordem cronológica:
pagamentos.append(50)   # dia 1
pagamentos.append(30)   # dia 2
pagamentos.append(70)   # dia 3
pagamentos.append(75)   # dia 4 
pagamentos.append(25)   # dia 5

#Imprimindo a lista de pagamentos:
print(pagamentos)

#Conferindo o saldo devedor atual:
saldo_devedor_atual=saldo_devedor_inicial+pagamentos[0]+pagamentos[1]+pagamentos[2]+pagamentos[3]+pagamentos[4]
print(saldo_devedor_atual)
# Out:
# [50, 30, 70, 75, 25]
# 0

# %% [markdown]
# ## 2\. Conjuntos

# %% [markdown]
# ### **2.1. Motivação**

# %% [markdown]
# Você trabalha como analista de dados de mídias sociais e precisa descobrir todas as *hashtags* que alcançaram o *top trending* do Twitter durante uma semana. Você já conseguiu as *hashtags* por dia da semana:

# %%
hashtags_seg = ['#tiago', '#joao', '#bbb']
hashtags_ter = ['#sarah', '#bbb', '#fiuk']
hashtags_qua = ['#gil', '#thelma', '#lourdes']
hashtags_qui = ['#rafa', '#fora', '#danilo']
hashtags_sex = ['#juliete', '#arthur', '#bbb']

# %% [markdown]
# Um simples concateção de listas fará com que a *hashtag* #bbb, entre outras, apareça mais de uma vez.

# %%
hashtags_semana = hashtags_seg + hashtags_ter + hashtags_qua + hashtags_qui + hashtags_sex
print(hashtags_semana)
# Out:
# ['#tiago', '#joao', '#bbb', '#sarah', '#bbb', '#fiuk', '#gil', '#thelma', '#lourdes', '#rafa', '#fora', '#danilo', '#juliete', '#arthur', '#bbb']

# %% [markdown]
# ### **2.2. Definição**

# %% [markdown]
# Armazenam sequências imutáveis e desordenadas valores, sem repetição. São do tipo `set`:

# %%
frutas = {'banana', 'maca', 'uva', 'uva'}

print(frutas)
print(type(frutas))
# Out:
# {'banana', 'maca', 'uva'}
# <class 'set'>

# %% [markdown]
# ### **2.3. Operações**

# %% [markdown]
# As operações da estrutura do tipo *set* são:
#
#
# *   `-` (diferença).

# %% [markdown]
# **Exemplo**: Países da europa.

# %%
norte_europa = {'reino unido', 'suecia', 'russia', 'noruega', 'dinamarca'}
escandinavia = {'noruega', 'dinamarca', 'suecia'}

# %%
norte_europa_nao_escandivano = norte_europa - escandinavia
print(norte_europa_nao_escandivano)
# Out:
# {'russia', 'reino unido'}

# %%
escandivano_nao_norte_europa = escandinavia - norte_europa
print(escandivano_nao_norte_europa)
# Out:
# set()

# %%
Profissionais_A = {'Analista de dados', 'Eng. Biomédico', 'Professor'}
Profissionais_B = {'Eng. Biomédico', 'Estudante', 'Analista de dados'}
DA_BE_nao_estudante = Profissionais_A - Profissionais_B
print('Não estudante: ', DA_BE_nao_estudante)
DA_BE_nao_professor = Profissionais_B - Profissionais_A
print('Não professor: ', DA_BE_nao_professor)
# Out:
# Não estudante:  {'Professor'}
# Não professor:  {'Estudante'}

# %%
comiloes_gordos_gulosos = {'João','Marcela','Paula','Paulo'}
gulosos_comiloes = {'João','Julia','André', 'Paulo'}

gulosos_nao_gordos = gulosos_comiloes - comiloes_gordos_gulosos
print(gulosos_nao_gordos)

#Converter para lista (isso elimina duplicatas)
selecionados = list(gulosos_nao_gordos)
print(type(selecionados))
print(selecionados)
# Out:
# {'Julia', 'André'}
# <class 'list'>
# ['Julia', 'André']

# %% [markdown]
# ### **2.4. Métodos**

# %% [markdown]
# São métodos nativos do Python que nos ajudam a trabalhar no dia a dia com conjuntos.

# %%
cursos = {'Exatas', 'Humanas', 'Biológicas'}
print(cursos)
# Out:
# {'Exatas', 'Humanas', 'Biológicas'}

# %%
# inserir um elemento no conjunto: set.add(val)
cursos.add('Saúde')
print(cursos)
# Out:
# {'Exatas', 'Humanas', 'Saúde', 'Biológicas'}

# %%
# remover um elemento no conjunto: set.remove(val)
cursos.remove('Saúde')
print(cursos)
# Out:
# {'Exatas', 'Humanas', 'Biológicas'}

# %%
assuntos_EQ = {'adsorção', 'termodinânica', 'cinética', 'reatores'}
assuntos_EQ.add('engenharia econômica')

#Após adição:
print(assuntos_EQ)

#Após remoção:
assuntos_EQ.remove('engenharia econômica')
print(assuntos_EQ)
# Out:
# {'engenharia econômica', 'termodinânica', 'adsorção', 'cinética', 'reatores'}
# {'termodinânica', 'adsorção', 'cinética', 'reatores'}

# %% [markdown]
# ### **2.5. Conversão**

# %% [markdown]
# Podemos converter conjuntos para lista e vice e versa.

# %%
times_paulistas = {'São Paulo', 'Palmeiras', 'Corinthians', 'Santos'}

print(times_paulistas)
print(type(times_paulistas))
# Out:
# {'Palmeiras', 'São Paulo', 'Santos', 'Corinthians'}
# <class 'set'>

# %%
print(list(times_paulistas))
print(type(list(times_paulistas)))
# Out:
# ['Palmeiras', 'São Paulo', 'Santos', 'Corinthians']
# <class 'list'>

# %% [markdown]
# ### **2.6. Revisitando a motivação**

# %%
print(hashtags_semana)
print(len(hashtags_semana))
# Out:
# ['#tiago', '#joao', '#bbb', '#sarah', '#bbb', '#fiuk', '#gil', '#thelma', '#lourdes', '#rafa', '#fora', '#danilo', '#juliete', '#arthur', '#bbb']
# 15

# %%
hashtags_semana = list(set(hashtags_seg + hashtags_ter + hashtags_qua + hashtags_qui + hashtags_sex))

print(hashtags_semana)
print(len(hashtags_semana))
# Out:
# ['#lourdes', '#rafa', '#danilo', '#tiago', '#thelma', '#joao', '#sarah', '#arthur', '#gil', '#juliete', '#fiuk', '#fora', '#bbb']
# 13

# %% [markdown]
# Criar um *script* com as **fontes de renda** geradas pelos meus **freelas** (todo o período) e armazená-los numa **lista sem repetição de elementos**.

# %%
fontes_renda_freelas_2020 =  ['Workana', 'Upwork', 'Workana' , 'Upwork', 
                              'Direto', 'Direto', 'Upwork', 'Freelancer',
                              'Guru', 'Fiverr', 'Fiverr', 'Fiverr']
fontes_renda_freelas_2021 =  ['Direto', 'Fiverr', 'Fiverr', 'Fiverr',
                              'Study.com', 'Study.com', 'Study.com',
                              'Workana']
fontes_renda_freela = list(set(fontes_renda_freelas_2020 + fontes_renda_freelas_2021))
print(fontes_renda_freela)
# Out:
# ['Upwork', 'Workana', 'Direto', 'Study.com', 'Fiverr', 'Guru', 'Freelancer']

# %% [markdown]
# ## 3\. Dicionários

# %% [markdown]
# ### **3.1. Motivação**

# %% [markdown]
# Para se conectar a uma rede wi-fi, você precisa de duas informações: o nome da rede e a senha de acesso. Quando você vai acessar uma nova rede, você encontra uma lista de redes disponíveis:

# %%
wifi_disponiveis = ['rede1', 'cnx_cnx', 'uai-fi', 'r3d3']
print(wifi_disponiveis)
# Out:
# ['rede1', 'cnx_cnx', 'uai-fi', 'r3d3']

# %% [markdown]
# Você consegue identificar quais são os nome de redes e suas respectivas senhas? Talvez uma `list` não seja a melhor opção para armazenar esse tipo de dado.

# %% [markdown]
# ### **3.2. Definição**

# %% [markdown]
# Armazenam sequências no formato chave-valor. São do tipo `dict`.

# %%
brasil = {'capital': 'Brasília', 'idioma': 'Português', 'populacao': 210}

print(brasil)
print(type(brasil))
# Out:
# {'capital': 'Brasília', 'idioma': 'Português', 'populacao': 210}
# <class 'dict'>

# %% [markdown]
# Não é permite chaves duplicadas.

# %%
carro = {
    'marca': 'Volkswagen',
    'modelo': 'Polo',
    'ano': 2021,
    'ano': 2004
}

print(carro)
# Out:
# {'marca': 'Volkswagen', 'modelo': 'Polo', 'ano': 2004}

# %%
fundos_imobiliarios = {
  'Recebíveis': ['MXRF11', 'VSHL11'],
  'Logística': 'RELG11',
  'Híbrido': 'TXRF11'
}

print(fundos_imobiliarios)
# Out:
# {'Recebíveis': ['MXRF11', 'VSHL11'], 'Logística': 'RELG11', 'Híbrido': 'TXRF11'}

# %% [markdown]
# Podemos criar dicionários compostos:

# %%
cadastro = {
    'andre': {
        'nome': 'Andre Perez', 
        'ano_nascimento': 1992, 
        'pais': {
            'pai': {
              'nome': '<nome-do-pai> Perez', 
              'ano_nascimento': 1971
            },
            'mae': {
              'nome': '<nome-da-mae> Perez', 
              'ano_nascimento': 1973
            },
        }
    }
}

print(cadastro)
# Out:
# {'andre': {'nome': 'Andre Perez', 'ano_nascimento': 1992, 'pais': {'pai': {'nome': '<nome-do-pai> Perez', 'ano_nascimento': 1971}, 'mae': {'nome': '<nome-da-mae> Perez', 'ano_nascimento': 1973}}}}

# %%
cadastro['andre']['pais']['mae']['ano_nascimento']
# Out:
# 1973

# %%
renda_variavel = {
    'Tipo': {
        'Ações':{
            'BBSE3':10,
            'ROMI3':20,
            'CMIN3':5,
            'TAEE3':50
        },
        'FIIs':{
            'MXRF11': 100,
            'TRXF11': 80,
            'RELG11': 20,
            'VSHL11': 15
        },
    },
}

print(renda_variavel)
# Out:
# {'Tipo': {'Ações': {'BBSE3': 10, 'ROMI3': 20, 'CMIN3': 5, 'TAEE3': 50}, 'FIIs': {'MXRF11': 100, 'TRXF11': 80, 'RELG11': 20, 'VSHL11': 15}}}

# %%
renda_variavel['Tipo']['Ações']['CMIN3']
renda_variavel['Tipo']['FIIs']['RELG11']
# Out:
# 20

# %% [markdown]
# ### **3.3. Operações**

# %%
credito = {'123': 750, '789': 980}

# %% [markdown]
# Elementos são acessados pela sua chave.

# %%
score_123 = credito['123']
score_789 = credito['789']

print(score_123)
print(score_789)
# Out:
# 750
# 980

# %% [markdown]
# Elementos são atualizados pela sua chave.

# %%
credito['123'] = 435
print(credito)
# Out:
# {'123': 435, '789': 980}

# %% [markdown]
# Para adicionar um novo elemento, basta criar um novo elemento chave-valor:

# %%
credito['456'] = 1000
print(credito)
# Out:
# {'123': 435, '789': 980, '456': 1000}

# %% [markdown]
# ### **3.4. Métodos**

# %% [markdown]
# São métodos nativos do Python que nos ajudam a trabalhar no dia a dia com dicionários.

# %%
artigo = dict(
    titulo='Modulo 02 | Python: Estruturas de Dados',
    corpo='Topicos, Aulas, Listas, Conjuntos, Dicionários, ...',
    total_caracteres=1530
)

# %%
# adicionar/atualizar um elemento pelo chave-valor: dict.update(dict)
print(artigo)
artigo.update({'total_caracteres': 7850})
print(artigo)

artigo['total_caracteres'] = 7850
# Out:
# {'titulo': 'Modulo 02 | Python: Estruturas de Dados', 'corpo': 'Topicos, Aulas, Listas, Conjuntos, Dicionários, ...', 'total_caracteres': 1530}
# {'titulo': 'Modulo 02 | Python: Estruturas de Dados', 'corpo': 'Topicos, Aulas, Listas, Conjuntos, Dicionários, ...', 'total_caracteres': 7850}

# %%
# remover um elemento pelo chave: dict.pop(key)
print(artigo)
total_caracteres = artigo.pop('total_caracteres')
print(artigo)
# Out:
# {'titulo': 'Modulo 02 | Python: Estruturas de Dados', 'corpo': 'Topicos, Aulas, Listas, Conjuntos, Dicionários, ...', 'total_caracteres': 7850}
# {'titulo': 'Modulo 02 | Python: Estruturas de Dados', 'corpo': 'Topicos, Aulas, Listas, Conjuntos, Dicionários, ...'}

# %%
projetos_freela = dict(
    topico = 'LaTeX',
    marketplace = 'Fiverr',
    buyer = 'Germany',
    rating = '5',
    budget_USD = 50
)
print('raw: ', projetos_freela)

#projetos_freela['buyer']='Netherlands'
projetos_freela.update({'buyer': 'Kwait'})
print(projetos_freela)

#projetos_freela_no_rating = projetos_freela.pop('rating')


projetos_freela_keys=list(projetos_freela.keys())
print(projetos_freela_keys)

projetos_freela_values=list(projetos_freela.values())
print(projetos_freela_values)
# Out:
# raw:  {'topico': 'LaTeX', 'marketplace': 'Fiverr', 'buyer': 'Germany', 'rating': '5', 'budget_USD': 50}
# {'topico': 'LaTeX', 'marketplace': 'Fiverr', 'buyer': 'Kwait', 'rating': '5', 'budget_USD': 50}
# ['topico', 'marketplace', 'buyer', 'rating', 'budget_USD']
# ['LaTeX', 'Fiverr', 'Kwait', '5', 50]

# %% [markdown]
# ### **3.5. Conversão**

# %% [markdown]
# Podemos converter as chaves e os items de um dicionário em uma lista.

# %%
artigo = dict(
    titulo='Modulo 02 | Python: Estruturas de Dados',
    corpo='Topicos, Aulas, Listas, Conjuntos, Dicionários, ...',
    total_caracteres=1530
)

# %%
chaves = list(artigo.keys())

print(chaves)
print(type(chaves))
# Out:
# ['titulo', 'corpo', 'total_caracteres']
# <class 'list'>

# %%
valores = list(artigo.values())

print(valores)
print(type(valores))
# Out:
# ['Modulo 02 | Python: Estruturas de Dados', 'Topicos, Aulas, Listas, Conjuntos, Dicionários, ...', 1530]
# <class 'list'>

# %% [markdown]
# ### **3.6. Revisitando a motivação**

# %%
wifi_disponiveis = []

# %%
rede = {'nome': 'rede1', 'senha': 'cnx_cnx'}
wifi_disponiveis.append(rede)

# %%
rede = {'nome': 'uai-fi', 'senha': 'r3d3'}
wifi_disponiveis.append(rede)

# %%
print(wifi_disponiveis)
# Out:
# [{'nome': 'rede1', 'senha': 'cnx_cnx'}, {'nome': 'uai-fi', 'senha': 'r3d3'}]

# %% [markdown]
# # Problema adicional (By VRO):
#
# Crie um *script* que armazene de maneira mais lógica e consistente as seguintes informações abaixo:
#
#
#
# ```
# ativos = ['FII', 'Ações' , 'Renda Fixa', 'REIT', 'O', 'STAG', 'NEOE3', 'QUAL3', 'RDB Nubank', 'CDB Banco Inter', 'VISC11', 'KNRI11']
# print(ativos)
# ```
#
# **DICA**: separe os ativos por classe/tipo de investimento.

# %%
ativos = ['FII', 'Ações' , 'Renda Fixa', 'REIT', 'O', 'STAG', 'NEOE3', 'QUAL3', 
          'RDB Nubank', 'CDB Banco Inter', 'VISC11', 'KNRI11']
print(ativos)
# Out:
# ['FII', 'Ações', 'Renda Fixa', 'REIT', 'O', 'STAG', 'NEOE3', 'QUAL3', 'RDB Nubank', 'CDB Banco Inter', 'VISC11', 'KNRI11']

# %%
ativos_organizados = []

#Adicionando os FIIs:
classe_1 = dict(
    tipo = 'FII',
    ativo = ['VISC11','KNRI11']
)

ativos_organizados.append(classe_1)

#Adicionando os REITs:
classe_2 = dict(
    tipo = 'REIT',
    ativo = ['O', 'STAG'],
)

ativos_organizados.append(classe_2)

#Adicionando os ativos de Renda Fixa:
classe_3 = dict(
    tipo = 'RF',
    ativo = ['RDB Nubank', 'CDB Banco Inter']
)

ativos_organizados.append(classe_3)


#Adicionando as Ações:
classe_4 = dict(
    tipo = 'Ação',
    ativo = ['NEOE3', 'QUAL3']
)

ativos_organizados.append(classe_4)

print('Lista organizada em termos do tipo de investimento e do ativo: ')
ativos_organizados
# Out:
# Lista organizada em termos do tipo de investimento e do ativo:
# [{'ativo': ['VISC11', 'KNRI11'], 'tipo': 'FII'},
#  {'ativo': ['O', 'STAG'], 'tipo': 'REIT'},
#  {'ativo': ['RDB Nubank', 'CDB Banco Inter'], 'tipo': 'RF'},
#  {'ativo': ['NEOE3', 'QUAL3'], 'tipo': 'Ação'}]
