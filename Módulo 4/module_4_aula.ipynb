# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Arquivos & Funções
# Caderno de **Aula**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Leitura;</li>
#   <li>Escrita;</li>
#   <li>Funções;</li>
#   <li>Escopo.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Aulas**

# %% [markdown]
# ## 1\. Leitura

# %% [markdown]
# ### **1.1. Configuração inicial**

# %% [markdown]
# Vamos utilizar uma função do **Google Colab** para criar arquivos para esse módulo. **Nota**: esse código **não** é do Python e sim da ferramenta.

# %% [markdown]
# **Arquivo CSV:** banco.csv

# %%
# %%writefile banco.csv
# age,job,marital,education,default,balance,housing,loan
# 30,unemployed,married,primary,no,1787,no,no
# 33,services,married,secondary,no,4789,yes,yes
# 35,management,single,tertiary,no,1350,yes,no
# 30,management,married,tertiary,no,1476,yes,yes
# 59,blue-collar,married,secondary,no,0,yes,no
# 35,management,single,tertiary,no,747,no,no
# 36,self-employed,married,tertiary,no,307,yes,no
# 39,technician,married,secondary,no,147,yes,no
# 41,entrepreneur,married,tertiary,no,221,yes,no
# 43,services,married,primary,no,-88,yes,yes
# Out:
# Overwriting banco.csv

# %% [markdown]
# ### **1.2. with / open**

# %% [markdown]
# Comando para ler arquivos.
#
# ```python
# with open(file='<caminho do arquivo>', mode='<modo de leitura>', encoding='<decodificador>') as <apelido>:
#   bloco de código
# ```

# %% [markdown]
# Os modos de leitura são:
#
# *   **r**: Abrir o arquivo para leitura (padrão).

# %% [markdown]
# ### **1.3. read**

# %% [markdown]
# Comando para ler todo o conteúdo de um arquivo.

# %%
conteudo = None

with open(file='./banco.csv', mode='r', encoding='utf8') as arquivo:
  conteudo = arquivo.read()

print(conteudo)
# Out:
# age,job,marital,education,default,balance,housing,loan
# 30,unemployed,married,primary,no,1787,no,no
# 33,services,married,secondary,no,4789,yes,yes
# 35,management,single,tertiary,no,1350,yes,no
# 30,management,married,tertiary,no,1476,yes,yes
# 59,blue-collar,married,secondary,no,0,yes,no
# 35,management,single,tertiary,no,747,no,no
# 36,self-employed,married,tertiary,no,307,yes,no
# 39,technician,married,secondary,no,147,yes,no
# 41,entrepreneur,married,tertiary,no,221,yes,no
# 43,services,married,primary,no,-88,yes,yes

# %% [markdown]
# ### **1.4. readline**

# %% [markdown]
# Comando para ler o conteúdo de um arquivo uma linha por vez.

# %%
conteudo = []

with open(file='./banco.csv', mode='r', encoding='utf8') as arquivo:
  linha = arquivo.readline() # lê a primeira linha
  while linha:
    conteudo.append(linha)
    linha = arquivo.readline() # lê uma nova linha, se a linha não existir, salva o valor None

print(conteudo)
# Out:
# ['age,job,marital,education,default,balance,housing,loan\n', '30,unemployed,married,primary,no,1787,no,no\n', '33,services,married,secondary,no,4789,yes,yes\n', '35,management,single,tertiary,no,1350,yes,no\n', '30,management,married,tertiary,no,1476,yes,yes\n', '59,blue-collar,married,secondary,no,0,yes,no\n', '35,management,single,tertiary,no,747,no,no\n', '36,self-employed,married,tertiary,no,307,yes,no\n', '39,technician,married,secondary,no,147,yes,no\n', '41,entrepreneur,married,tertiary,no,221,yes,no\n', '43,services,married,primary,no,-88,yes,yes']

# %%
for linha in conteudo:
  print(linha)
# Out:
# age,job,marital,education,default,balance,housing,loan
#
# 30,unemployed,married,primary,no,1787,no,no
#
# 33,services,married,secondary,no,4789,yes,yes
#
# 35,management,single,tertiary,no,1350,yes,no
#
# 30,management,married,tertiary,no,1476,yes,yes
#
# 59,blue-collar,married,secondary,no,0,yes,no
#
# 35,management,single,tertiary,no,747,no,no
#
# 36,self-employed,married,tertiary,no,307,yes,no
#
# 39,technician,married,secondary,no,147,yes,no
#
# 41,entrepreneur,married,tertiary,no,221,yes,no
#
# 43,services,married,primary,no,-88,yes,yes

# %% [markdown]
# **Exemplo**: Extraindo os valores da primeira coluna (idade).

# %%
idades = []

with open(file='./banco.csv', mode='r', encoding='utf8') as arquivo:
  linha = arquivo.readline() # lê o cabeçalho
  linha = arquivo.readline() # lê a primeira linha
  while linha:
    linha_separada = linha.split(sep=',') # quebra a string nas virgulas e salva os resultados em uma lista
    idade = linha_separada[0] # seleciona o primeiro elemento da lista
    idade = int(idade) # converte o valor de string para integer (inteiro)
    idades.append(idade) # salva o valor na lista de idades
    linha = arquivo.readline() # lê uma nova linha, se a linha não existir, salva o valor None

print(idades)
# Out:
# [30, 33, 35, 30, 59, 35, 36, 39, 41, 43]

# %%
balancos = []

with open(file='./banco.csv', mode='r', encoding='utf8') as arquivo:
  linha = arquivo.readline() # lê o cabeçalho
  linha = arquivo.readline() # lê a primeira linha
  while linha:
    linha_separada = linha.split(sep=',') # quebra a string nas virgulas e salva os resultados em uma lista
    balanco = linha_separada[-3] # seleciona o primeiro elemento da lista
    balanco = int(balanco) # converte o valor de string para integer (inteiro)
    balancos.append(balanco) # salva o valor na lista de idades
    linha = arquivo.readline() # lê uma nova linha, se a linha não existir, salva o valor None

print(balancos)
# Out:
# [1787, 4789, 1350, 1476, 0, 747, 307, 147, 221, -88]

# %% [markdown]
# ---
# ### **Criando um csv**

# %%
# %%writefile biomaterials.csv
# Biomaterial, Class, Classification
# CoCr, Metal, Synthetic
# Bioglass-ceramic, Ceramic, Syntetic
# HAp, Ceramic, Natural
# HA, Natural, Natural
# UHMWPE, Polymer, Synthetic
# Cellulose, Polymer, Natural
# Out:
# Overwriting biomaterials.csv

# %% [markdown]
# ### **Lendo esse arquivo**

# %%
Dados_biomateriais = None

with open(file='./biomaterials.csv',mode='r',encoding='utf8') as plan_biomaterials:
  Dados_biomateriais = plan_biomaterials.read()

print(Dados_biomateriais)
# Out:
# Biomaterial, Class, Classification
# CoCr, Metal, Synthetic
# Bioglass-ceramic, Ceramic, Syntetic
# HAp, Ceramic, Natural
# HA, Natural, Natural
# UHMWPE, Polymer, Synthetic
# Cellulose, Polymer, Natural

# %% [markdown]
# ## 2\. Escrita

# %% [markdown]
# ### **2.1. with / open**

# %% [markdown]
# Comando para ler/escrever arquivos.
#
# ```python
# with open(file='<caminho do arquivo do arquivo>', mode='<modo de leitura/escrita>', encoding='<decodificador>') as <apelido>:
#   bloco de código
# ```

# %% [markdown]
# Os modos de leitura são:
#
# *   **r**: Abrir o arquivo para leitura (padrão);
# *   **w**: Abrir o arquivo para escrita (sobreescreve o arquivo original).
# *   **a**: Abrir o arquivo para acrescentar (não sobreescreve o arquivo original)

# %% [markdown]
# ### **2.2. write**

# %% [markdown]
# Comando para escrever em um arquivo, se o arquivo não existir, ele será criado.

# %% [markdown]
# - Modo de escrita (w).

# %%
with open(file='idades.csv', mode='w', encoding='utf8') as fp:
  linha = 'idade' + '\n'
  fp.write(linha)
  for idade in idades:
    linha = str(idade) + '\n'
    fp.write(linha)

# %% [markdown]
# ---
# **Criando um csv com a classe de biomaterial**:

# %%
classes = []

with open(file='./biomaterials.csv',mode='r',encoding='utf8') as file_csv:
  linha = file_csv.readline() # lê o cabeçalho
  linha = file_csv.readline() # lê a primeira linha

  while linha:
    linha_separada = linha.split(sep=',')
    classe = linha_separada[-2]
    classes.append(classe)
    linha = file_csv.readline()

print(classes)
# Out:
# [' Metal', ' Ceramic', ' Ceramic', ' Natural', ' Polymer', ' Polymer']

# %%
with open(file='class_biomaterials.csv',mode='w',encoding='utf8') as filepointer:
  linha = 'Classe do biomaterial' + '\n'
  filepointer.write(classe)

  for classe in classes:
    linha=classe + '\n'
    filepointer.write(linha)

# %% [markdown]
#  - Modo de acréscimo (a).

# %%
with open(file='idades.csv', mode='a', encoding='utf8') as fp:
  for idade in idades:
    linha = str(idade + 100) + '\n'
    fp.write(linha)

# %% [markdown]
# **Exemplo**: Copiando um arquivo com uma extensão diferente.

# %%
# %%writefile banco-texto.txt
# age,job,marital,education,default,balance,housing,loan
# 30,unemployed,married,primary,no,1787,no,no
# 33,services,married,secondary,no,4789,yes,yes
# 35,management,single,tertiary,no,1350,yes,no
# 30,management,married,tertiary,no,1476,yes,yes
# 59,blue-collar,married,secondary,no,0,yes,no
# 35,management,single,tertiary,no,747,no,no
# 36,self-employed,married,tertiary,no,307,yes,no
# 39,technician,married,secondary,no,147,yes,no
# 41,entrepreneur,married,tertiary,no,221,yes,no
# 43,services,married,primary,no,-88,yes,yes
# Out:
# Overwriting banco-texto.txt

# %%
with open(file='./banco-texto.txt', mode='r', encoding='utf8') as leitura:
  with open(file='./banco-csv.csv', mode='w', encoding='utf8') as escrita:
    linha = leitura.readline()
    while linha:
      escrita.write(linha)
      linha = leitura.readline()

# %% [markdown]
# ## 3\. Funções

# %% [markdown]
# ### **3.1. Motivação**

# %% [markdown]
# Você trabalha na bolsa de valores e precisa simular o retorno de um investimento para diversos cenários:

# %%
valor_inicial, taxa_juros_anual, anos = 1000.00, 0.05, 10

valor_final = valor_inicial
for ano in range(1, anos+1):
  valor_final = valor_final * (1 + taxa_juros_anual)
valor_final = round(valor_final, 2)
print(f'Para um valor inicial de R$ {valor_inicial} e uma taxa de juros anual de {taxa_juros_anual}, em {anos} anos você terá R$ {valor_final}') 

valor_inicial, taxa_juros_anual, anos = 1020.00, 0.03, 10

valor_final = valor_inicial
for ano in range(1, anos+1):
  valor_final = valor_final * (1 + taxa_juros_anual)
valor_final = round(valor_final, 2)
print(f'Para um valor inicial de R$ {valor_inicial} e uma taxa de juros anual de {taxa_juros_anual}, em {anos} anos você terá R$ {valor_final}')
# Out:
# Para um valor inicial de R$ 1000.0 e uma taxa de juros anual de 0.05, em 10 anos você terá R$ 1628.89
# Para um valor inicial de R$ 1020.0 e uma taxa de juros anual de 0.03, em 10 anos você terá R$ 1370.79

# %% [markdown]
# Como podemos fazer para reaproveitar o código e evitar repetições?

# %% [markdown]
# ### **3.2. Definição**

# %% [markdown]
# Um bloco de código que só executado quando chamado.

# %% [markdown]
# ```python
# def <nome>(<param 1>, <param 2>, ...):
#   bloco de código
#   return <valor de retorno>
# ```
#
# ```python
# var = <nome da funcao>(<param 1>, <param 2>, ...)
# ```

# %%
def imprime(mensagem: str):
  print(mensagem)

# %%
texto = 'Fala pessoal, meu nome é André Perez!'

# %%
imprime(mensagem='Fala pessoal, meu nome é André Perez!')
# Out:
# Fala pessoal, meu nome é André Perez!

# %% [markdown]
# ### **3.3. Retorno**

# %% [markdown]
# Toda função retorna pelo menos um valor, se não específicado, retorna o valor nulo.

# %%
def maiusculo(texto: str) -> str:
  text_maiusculo = texto.upper()
  return text_maiusculo

# %%
def minusculo(texto: str) -> str:
  texto_minusculo = texto.lower()
  return texto_minusculo

texto = 'VINICIUS'
teste = minusculo(texto)
print(teste)
# Out:
# vinicius

# %%
nome = 'André Perez'
print(nome)

nome_maiusculo = maiusculo(texto=nome)
print(nome_maiusculo)
# Out:
# André Perez
# ANDRÉ PEREZ

# %%
def extrair_usuario_email_provedor(email: str) -> (str, str):
  email_separado = email.split(sep='@')
  usuario = email_separado[0]
  provedor = email_separado[1]
  return usuario, provedor

# %%
email = 'andre.perez@gmail.com'
usuario, provedor = extrair_usuario_email_provedor(email=email)
print(usuario)
print(provedor)
# Out:
# andre.perez
# gmail.com

# %% [markdown]
# ### **3.3. Parâmetros**

# %% [markdown]
# Parâmetros são os valores que a passamos na chamada da função.

# %% [markdown]
#  - Função sem parâmetro:

# %%
def pi() -> float:
  return 3.14159265359

# %%
pi = pi()
print(pi)
# Out:
# 3.14159265359

# %%
def imprime_pi() -> None:
  print(3.14159265359)
  return None

# %%
imprime_pi()
# Out:
# 3.14159265359

# %% [markdown]
#  - Função com parâmetro:

# %%
def escreve_arquivo_csv(nome: str, cabecalho: str, conteudos: list) -> bool:

  try: 

    with open(file=nome, mode='w', encoding='utf8') as fp:
      linha = cabecalho + '\n'
      fp.write(linha)
      for conteudo in conteudos:
        linha = str(conteudo) + '\n'
        fp.write(linha)

  except Exception as exc:
    
    print(exc)
    return False

  return True

# %%
nome = 'idades-funcao-erro.csv'
cabecalho = 'idade'
# conteudos = [30, 33, 35, 30, 59, 35, 36, 39, 41, 43]
conteudos = 10

escreveu_com_sucesso = escreve_arquivo_csv(nome=nome, cabecalho=cabecalho, conteudos=conteudos)
print(escreveu_com_sucesso)
# Out:
# 'int' object is not iterable
# False

# %% [markdown]
# ### **3.4. Revisitando a motivação**

# %%
def juros_compostos_anual(valor_inicial: float, taxa_juros_anual: float, anos: int) -> float:
  valor_final = valor_inicial
  for ano in range(1, anos+1):
    valor_final = valor_final * (1 + taxa_juros_anual)
  valor_final = round(valor_final, 2)
  print(f'Para um valor inicial de R$ {valor_inicial} e uma taxa de juros anual de {taxa_juros_anual}, em {anos} anos você terá R$ {valor_final}') 
  return valor_final

valor_inicial, taxa_juros_anual, anos = 1000.00, 0.05, 10
valor_final = juros_compostos_anual(valor_inicial=valor_inicial, taxa_juros_anual=taxa_juros_anual, anos=anos)

valor_inicial, taxa_juros_anual, anos = 1020.00, 0.03, 10
valor_final = juros_compostos_anual(valor_inicial=valor_inicial, taxa_juros_anual=taxa_juros_anual, anos=anos)
# Out:
# Para um valor inicial de R$ 1000.0 e uma taxa de juros anual de 0.05, em 10 anos você terá R$ 1628.89
# Para um valor inicial de R$ 1020.0 e uma taxa de juros anual de 0.03, em 10 anos você terá R$ 1370.79

# %% [markdown]
# ---
# ###**Calculando o *magic number* para Fundos Imobiliários**:
#
# **Problema 1:** Criar uma função para calcular o *Magic Number* para um Fundo Imobiliário (FII).
#
# &nbsp;
#
# Equação para o cálculo do *Magic Number* - número de cotas necessárias para que o rendimento mensal possa comprar uma nova cota ao ser reinvistido.
#
# &nbsp;
#
# \begin{equation}
#   MN = \frac{Valor \ da \ cota}{Dividendo} \ [R\$]
# \end{equation}
#
# &nbsp;
#
# **Problema 2:**
#
# Calcular esse valor para uma série de Fundos Imobiliários (FIIs) utilizando essa função e armazenar o resultados  em um arquivo **csv**.
#
# ---

# %% [markdown]
# **Resolução Problema 1:**

# %%
#Pedindo ao usuário para entrar o FII, o vlaor da cota e o dividendo:
FII_escolhido = str(input('Entre o código FII de interesse: '))
valor_cota = float(input('Entre o valor da cota (R$): '))
dividendo = float(input('Entre o último dividendo (R$): '))

#Criando a função para calcular o magic number para um determinado FII:
def Calcula_Magic_Number(FII_escolhido: str, valor_cota: float, dividendo: float) -> (str, int):
  Magic_Number = int(round(valor_cota / dividendo))
  print(f'O magic number (número de cotas para cobrir uma nova cota com o rendimento) para o FII "{FII_escolhido}" é:')
  return print(f'{Magic_Number} cotas.')

#Calculando o magic number para os dados informados pelo usuário:
Calcula_Magic_Number(FII_escolhido, valor_cota, dividendo)
# Out:
# Entre o código FII de interesse: RELG11
# Entre o valor da cota (R$): 91.37
# Entre o último dividendo (R$): 0.70
# O magic number (número de cotas para cobrir uma nova cota com o rendimento) para o FII "RELG11" é:
# 131 cotas.

# %% [markdown]
# **Resolução Problema 2:**

# %%
FIIs = ['MXRF11', 'TRXF11']
cotas = [10.03, 106.10]
dividendos = [0.07, 0.70]

Dados_FIIs = {'FII': FIIs,
                'Cota': cotas,
                'Dividendo': dividendos,
}

#Criando uma chave "Magic Number" sem valores:
Magic_Numbers = []
Dados_FIIs['Magic Number'] = Magic_Numbers

#Definindo a função para calcular o "Magic Number":
def Calculo_do_magic_number(cota: float ,dividendo: float) -> float:
  FII_magic_number = cota / dividendo
  return (int(round(FII_magic_number)))

Dados_FIIs
# Out:
# {'Cota': [10.03, 106.1],
#  'Dividendo': [0.07, 0.7],
#  'FII': ['MXRF11', 'TRXF11'],
#  'Magic Number': []}

# %% [markdown]
# ## 4\. Escopo

# %% [markdown]
# ### **4.1. Definição**

# %% [markdown]
# Define o ciclo de vida de uma variável.

# %% [markdown]
#  - Escopo de função.

# %%
def soma_lista(numeros: list) -> int:
  s = 0
  for numero in numeros:
    s = s + numero
  return s

# %%
soma = soma_lista(numeros=[2] * 20)
print(soma)
# Out:
# 40

# %%
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-0ff1b7208845> in <module>()
# ----> 1 print(s)
#
# NameError: name 's' is not defined

# %% [markdown]
#  - Escopo de estrutura condicional / repetição.

# %%
if True:
  x = 100
else:
  w = 50

print(x)
