# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Visualização de Dados II
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Distribuições: Histograma, KDE e Box Plot;</li>
#   <li>Correlação: Gráfico de Disperção e Mapa de Calor.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# Nestes exercícios, você deve decidir qual é o gráfico visto em aula que melhor visualiza uma base de dados. Após decidir, você deverá criar a visualização usando o conteúdo exposto durante a aula e adicionar um pequeno parágrafo sobre um insights que pode ser extraido do gráfico.

# %% [markdown]
# ## 1\. Preços `outliers` de diamante

# %%
import seaborn as sns

data = sns.load_dataset("diamonds")
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# gráfico do exercício 1

diamonds = data[['price']]
diamonds

with sns.axes_style('darkgrid'):
  grafico_1 = sns.boxplot(x='price',data=diamonds)
  grafico_1.set(title='Boxplot: outliers de preço dos diamantes',
                xlabel='Preço (U$D)')

# %% [markdown]
# **Insight do gráfico 1**: Conforme mostra o *boxplot* valores acima de $125000 são considerados outliers. Basicamente, existem muitos deles no preço dos diamantes.

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Correlação entre o do preço do diamante com seu peso (`carat`) agrupados por sua transparêcia (`clarity`)

# %%
import seaborn as sns

data = sns.load_dataset("diamonds")
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# gráfico do exercício 2

diamonds = data[['price', 'carat', 'clarity']]
diamonds_grouped = diamonds.groupby('clarity').mean().corr()

with sns.axes_style('darkgrid'):
  grafico_2 = sns.heatmap(diamonds_grouped, annot=True)

# %% [markdown]
# **Insight do gráfico 2**: Como se pode ver no *heatmap* o preço e o peso do diamente estão forte e positivamente correlacionados. Quanto maior o peso do diamante, maior será o preço.

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Distribuição contínua aproximada do peso (`weight`) de carros

# %%
import seaborn as sns

data = sns.load_dataset("mpg")
data.head()
# Out:
#     mpg  cylinders  displacement  ...  model_year  origin                       name
# 0  18.0          8         307.0  ...          70     usa  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...          70     usa          buick skylark 320
# 2  18.0          8         318.0  ...          70     usa         plymouth satellite
# 3  16.0          8         304.0  ...          70     usa              amc rebel sst
# 4  17.0          8         302.0  ...          70     usa                ford torino
#
# [5 rows x 9 columns]

# %%
# gráfico do exercício 3

cars = data[['weight']]

with sns.axes_style('darkgrid'):
  grafico_3 = sns.histplot(x='weight',data=cars,kde=True)
  grafico_3.set(title='Distribuição do peso de carros',
                xlabel='peso (u.m.)',
                ylabel='Contagem')

# %% [markdown]
# **Insight do gráfico 3**: A distribuição do peso dos carros não segue uma distribuição normal. Além disso, a probabilidade de haver carros de até 3000 u.m. (unidades de massa) é bem maior a carros com mais de 4000 u.m.

# %% [markdown]
# ---
